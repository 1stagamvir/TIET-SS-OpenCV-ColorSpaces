# %% [markdown]
# <a href="https://colab.research.google.com/github/1stagamvir/TIET-SS-OpenCV-ColorSpaces/blob/main/OpenCV_ColorSpaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image = cv2.imread('/content/logo.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
image = cv2.imread('/content/logo.jpg',0)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=1000x1000>

# %%
image = cv2.imread('/content/logo.jpg')
if image is None:
    print("Error: Could not load the image. Please check the file path.")
else:
    from google.colab.patches import cv2_imshow
    cv2_imshow(image)
    B, G, R = cv2.split(image)
    print(B.shape)
    print(G.shape)
    print(R.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>
# (1000, 1000)
# (1000, 1000)
# (1000, 1000)

# %%
import numpy as np
# Let's create a matrix of zeros
# with dimensions of the image h x w
zeros = np.zeros(image.shape[:2], dtype = "uint8")
from google.colab.patches import cv2_imshow
cv2_imshow(cv2.merge([zeros, zeros, R]))
cv2_imshow(cv2.merge([zeros, G, zeros]))
cv2_imshow(cv2.merge([B, zeros, zeros]))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>
# <PIL.Image.Image image mode=RGB size=1000x1000>
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
image = cv2.imread('/content/logo.jpg')

# OpenCV's 'split' function splites the image into each color index
B, G, R = cv2.split(image)

# Let's re-make the original image,
merged = cv2.merge([B, G, R])
from google.colab.patches import cv2_imshow
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
merged = cv2.merge([B+100, G, R])
from google.colab.patches import cv2_imshow
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
image = cv2.imread('/content/logo.jpg')
# Convert to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
from google.colab.patches import cv2_imshow
cv2_imshow(hsv_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>
